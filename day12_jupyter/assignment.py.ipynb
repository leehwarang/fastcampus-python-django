# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
response = requests.get('http://www.0404.go.kr/m/dev/country_view.do?idx=69')

# %%
response
# Out:
# <Response [200]>

# %%
result = bs(response.text, 'html.parser')

# %%
result
# Out:
# <!DOCTYPE html>
#
# <html lang="Ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, minimum-scale=1, user-scalable=yes" name="viewport"/>
# <title>외교부 해외안전여행</title>
# <link href="/m/css/base.css" rel="stylesheet" type="text/css"/>
# <link href="/m/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="/m/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="/m/css/board.css" rel="stylesheet" type="text/css"/>
# <link href="/m/css/contents.css" rel="stylesheet" type="text/css"/>
# <link href="/m/css/jquery.mmenu.all.css" rel="stylesheet" type="text/css"/>
# <script src="/m/js/jquery-1.11.1.min.js" type="text/javascript"></script>
# <script src="/m/js/jquery.mmenu.min.all.js" type="text/javascript"></script>
# <script src="/m/js/ender.js" type="text/JavaScript"></script>
# <script src="/m/js/link.js" type="text/javascript"></script>
# <script src="/m/js/common.js" type="text/javascript"></script>
# ...

# %%
a = result.find('div', {'class':'map_box'})

# %%
a
# Out:
# <div class="map_box" style="margin:15px 0 0 0;">
# <img alt="미국 여행경보지도" src="/imgsrc.mofa?atch_file_id=COUNTRY_69&amp;file_sn=3" style="max-width:100%"/>
# </div>

# %%
b = result.find_all('img')

# %%
b.find_all('')
# Out:
# [<img alt="외교부 해외안전여행 - 알고 챙기고 떠나고" src="/m/images/layout/img_logo.png"/>,
#  <img alt="미국 국기" height="52" src="/imgsrc.mofa?atch_file_id=COUNTRY_69&amp;file_sn=1" width="78"/>,
#  <img alt="미국 여행경보지도" src="/imgsrc.mofa?atch_file_id=COUNTRY_69&amp;file_sn=3" style="max-width:100%"/>,
#  <img alt="미국대사관" src="https://www.0404.go.kr/images/editor/images/000008/3usa20131219.jpg" style="BORDER-TOP: rgb(0,0,0) 0px solid; BORDER-RIGHT: rgb(0,0,0) 0px solid; VERTICAL-ALIGN: baseline; BORDER-BOTTOM: rgb(0,0,0) 0px solid; BORDER-LEFT: rgb(0,0,0) 0px solid" title="미국대사관"/>,
#  <img alt="워싱턴 영사과" src="https://www.0404.go.kr/images/editor/images/000008/4usa20131219.jpg" style="BORDER-TOP: rgb(0,0,0) 0px solid; BORDER-RIGHT: rgb(0,0,0) 0px solid; VERTICAL-ALIGN: baseline; BORDER-BOTTOM: rgb(0,0,0) 0px solid; BORDER-LEFT: rgb(0,0,0) 0px solid" title="워싱턴 영사과"/>,
#  <img alt="페이스북" src="/m/images/layout/btn_face.png"/>,
#  <img alt="유투브" src="/m/images/layout/btn_utov.png"/>,
# ...
